# %%
import numpy as np
import matplotlib.pyplot as plt

#import results1
import results2

# %%
def plot_observables(L_values, model_label="XY"):
    T_vals = None 
    fig, axs = plt.subplots(2, 2, figsize=(14, 10), constrained_layout=True)
    for L in L_values:
        if model_label.upper() == "XY":
            T_vals = np.linspace(0.01, 2.0, 25)
            E = globals()[f'E_XY_{L}']
            M = globals()[f'M_XY_{L}']
            Cv = globals()[f'Cv_XY_{L}']
            Chi = globals()[f'Chi_XY_{L}']
        else:
            T_vals = np.linspace(1.0, 3.0, 25)
            E = globals()[f'E_{L}']
            M = globals()[f'M_{L}']
            Cv = globals()[f'Cv_{L}']
            Chi = globals()[f'Chi_{L}']
            
        N = L**2 # Total number of spins for normalization
        
        # 1. Mean Energy per spin
        axs[0, 0].plot(T_vals, E / N, label=f'L = {L}')
        
        # 2. Mean Magnetization per spin
        axs[0, 1].plot(T_vals, abs(M) / N, label=f'L = {L}')
        
        # 3. Heat Capacity per spin
        axs[1, 0].plot(T_vals, Cv / N, label=f'L = {L}')
        
        # 4. Magnetic Susceptibility per spin
        axs[1, 1].plot(T_vals, Chi / N, label=f'L = {L}')
    # Format y-labels
    axs[0, 0].set_ylabel(r'Mean Energy per Spin $\langle E \rangle / L^2$')
    axs[0, 1].set_ylabel(r'Mean Magnetization per Spin $\langle |M| \rangle / L^2$')
    axs[1, 0].set_ylabel(r'Specific Heat $C_V / L^2$')
    axs[1, 1].set_ylabel(r'Magnetic Susceptibility $\chi / L^2$')
    axs[1, 0].set_ylim(ymax=5,ymin=-1)
    axs[1, 1].set_ylim(ymax=1000, ymin=-1)
    # Format all subplots
    for ax in axs.flat:
        ax.set_xlabel('Temperature $T$')
        ax.grid(True, linestyle='--', alpha=0.6)
        ax.legend()
    fig.suptitle(f'{model_label} Model', fontsize=18)
    plt.show()

# %%
# %load results3.py
import numpy as np

# Ising Model Results

E_16 = np.array([-511.2719391397623, -510.6252403637427, -509.61382073637935, -508.12380674875294, -506.03153545465545, -503.1954296080812, -499.48644804511514, -494.71246251041316, -488.7258563302937, -481.25391106493237, -472.0528305745596, -460.79734566204894, -446.86029438635484, -429.49483766756464, -407.3056640994314, -379.267167132281, -346.8739527812689, -315.38113891112823, -289.5305772297027, -269.60424362144636, -253.41224913088672, -240.0872406141363, -228.56567484932623, -218.36676322383855, -209.34155312660195])
M_16 = np.array([255.81431784436018, 255.64656593480174, 255.38037505369414, 254.9816028814413, 254.4100404396627, 253.61531539259695, 252.54444376579312, 251.11584421759176, 249.244227505085, 246.78203576714668, 243.54070769835548, 209.27540173723426, 102.41321233960784, 52.119737406314606, 5.545833732043401, -2.5836291616653058, 1.875643081243596, -0.49695667128040616, -0.235293027646866, 0.6001452989985665, 0.017390857325963682, -0.024411438505969676, 0.3217221792827478, 0.059101204408940115, 0.20285176672148356])
